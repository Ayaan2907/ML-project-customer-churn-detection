# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('churn.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
sns.set_style(style="whitegrid")
plt.figure(figsize=(12,10))

# %% [markdown]
# # Plotting
# Plotting different charts

# %%
sns.countplot(x="Exited", data=df)
plt.title("exited customers")
# Out:
# Text(0.5, 1.0, 'exited customers')

# %%
sns.histplot(data=df, x='Age', bins=30, kde=True)
plt.title('Distribution of Customer Ages')
# Out:
# Text(0.5, 1.0, 'Distribution of Customer Ages')

# %%
sns.scatterplot(data=df, x='CreditScore', y='Age', hue='Exited')
plt.title('Credit Score vs. Age')
# Out:
# Text(0.5, 1.0, 'Credit Score vs. Age')

# %%
sns.boxplot(data=df, x='Exited', y='Balance')
plt.title('Balance distribution by churned')
# Out:
# Text(0.5, 1.0, 'Balance distribution by churned')

# %%
sns.boxenplot(data=df, x='Exited', y='EstimatedSalary')
plt.title('Estimated Salary distribution by churned')
# Out:
# Text(0.5, 1.0, 'Estimated Salary distribution by churned')

# %%
sns.boxplot(data=df, x='Exited', y='CreditScore')
plt.title('Credit Score distribution by churned')
# Out:
# Text(0.5, 1.0, 'Credit Score distribution by churned')

# %% [markdown]
# # Column Separation

# %%
feature = df.drop('Exited', axis=1)
feature
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
target = df['Exited']
target
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
feature = feature.drop(['CustomerId', 'RowNumber', 'Surname' ], axis=1)
feature
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
# from google.colab import sheets
# sheet = sheets.InteractiveSheet(df=feature)

# %%
feature = feature.dropna() #in case missing data, drop it ( u have to deal it case by case in other projects )
feature
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
# encoding categorical features, models only understand numerics, boolen, so to
# convert into onehardcoding we use this
features = pd.get_dummies(feature, columns=['Geography', 'Gender'])
features
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_France  Geography_Germany  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train[0]
# Out:
# array([ 0.35649971, -0.6557859 ,  0.34567966, -1.21847056,  0.80843615,
#         0.64920267,  0.97481699,  1.36766974,  1.00150113, -0.57946723,
#        -0.57638802, -0.91324755,  0.91324755])

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb


import pickle # used to save ML models

# %%
lr_model = LogisticRegression(random_state=42)
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
lr_predications = lr_model.predict(X_test)
lr_predications
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(2000,))

# %%
accuracy = accuracy_score(y_test, lr_predications)
accuracy
# Out:
# 0.811

# %% [markdown]
# # Note
#
# We are training our model (first training iteration)

# %%
def evaluate_and_save_model(model, X_train, X_test, y_train, y_test, filename):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("-------------------------")
    print(f"{model.__class__.__name__}: Accuracy = {accuracy:.4f}")
    print(f"Classification Report : \n {classification_report(y_test, y_pred)}")
    print(confusion_matrix(y_test, y_pred))

    with open(filename, 'wb') as file:
        pickle.dump(model, file)
    print(f"Model saved as {filename}")

# %%
xgb_model = xgb.XGBClassifier(random_state=42)
evaluate_and_save_model(xgb_model, X_train, X_test, y_train, y_test, 'models/xgb_model.pkl')

dt_model = DecisionTreeClassifier(random_state=42)
evaluate_and_save_model(dt_model, X_train, X_test, y_train, y_test, 'models/dt_model.pkl')

rf_model = RandomForestClassifier(random_state=42)
evaluate_and_save_model(rf_model, X_train, X_test, y_train, y_test, 'models/rf_model.pkl')

nb_model = GaussianNB()
evaluate_and_save_model(nb_model, X_train, X_test, y_train, y_test, 'models/nb_model.pkl')

knn_model = KNeighborsClassifier()
evaluate_and_save_model(knn_model, X_train, X_test, y_train, y_test, 'models/knn_model.pkl')

svm_model = SVC(random_state=42, probability=True)
evaluate_and_save_model(svm_model, X_train, X_test, y_train, y_test, 'models/svm_model.pkl')
# Out:
# -------------------------
# XGBClassifier: Accuracy = 0.8580
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91      1607
#            1       0.69      0.50      0.58       393
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000
#
# [[1521   86]
#  [ 198  195]]
# Model saved as models/xgb_model.pkl
# -------------------------
# DecisionTreeClassifier: Accuracy = 0.7805
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1607
#            1       0.45      0.51      0.48       393
#
#     accuracy                           0.78      2000
#    macro avg       0.66      0.68      0.67      2000
# weighted avg       0.79      0.78      0.79      2000
#
# [[1362  245]
#  [ 194  199]]
# ...

# %% [markdown]
# # Note
#
# Based on the above response, we can see the xgboost model
# has a higher precision which is what we need
#
# And lets see which featueres are contributing the most in the prediciton

# %%
# ranking the importance features using xgboost which are helpful in the judgement
feature_importance = xgb_model.feature_importances_
feature_names = features.columns

feature_importance
feature_names
# Out:
# Index(['CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Geography_France',
#        'Geography_Germany', 'Geography_Spain', 'Gender_Female', 'Gender_Male'],
#       dtype='object')

# %%
# dataframe with feature importances (making a set)
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': feature_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
feature_importance_df
# Out:
#               Feature  Importance
# 4       NumOfProducts    0.288658
# 6      IsActiveMember    0.194039
# 1                 Age    0.113240
# 9   Geography_Germany    0.099048
# 3             Balance    0.053883
# 11      Gender_Female    0.042302
# 8    Geography_France    0.041067
# 10    Geography_Spain    0.037478
# 0         CreditScore    0.034965
# 7     EstimatedSalary    0.033707
# 2              Tenure    0.033399
# 5           HasCrCard    0.028215
# 12        Gender_Male    0.000000

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df)
plt.title('Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# # Improvements
#
#   1. Feature Engineering
#     Creating new features on the dataset based on existing features to help better train the model
#
#   2. SMOTE (Synthetic Minority Over-sampling TEchnique)
#     a technique used in machine learning to address class imbalance in datasets by artificially increasing the number of minority class samples
#
#   3. Ensembeling
#     This is like asking multiple experts their opinion and then taking a majority vote, process of combining output of multiple models to get a new model trained.
#
#   > Hyper parameter tuning, but not for this now

# %%
# feature engineering
# lets add new features (lets add CLV : customer long term value, a multiple of balance and salary)
feature['CLV'] = df['Balance'] * df['EstimatedSalary']/100000
feature
# added new columns CLV
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary            CLV
# ...

# %%
# lets group our features ( age )
feature['AgeGroup'] = pd.cut(df['Age'], bins=[0,30,45, 60, 100], labels=['young', 'middle', 'senior', 'old'])
feature
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
# ...

# %%
# adding new feature
feature['TenureAgeRatio'] = df['Tenure'] / df['Age']
feature
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
# ...

# %%
# Now we again need to  convert categorical variables to numeric or boolen
feature = pd.get_dummies(feature, drop_first=True)
feature
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary            CLV  TenureAgeRatio  \
# 0                  1        101348.88       0.000000        0.047619
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(feature, target, test_size=0.2, random_state=42)

# %%
# scale the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
xgboost_model = xgb.XGBClassifier(random_state=42)
evaluate_and_save_model(xgboost_model, X_train, X_test, y_train, y_test, 'models/xgboost_featureEng_model.pkl')
# Out:
# -------------------------
# XGBClassifier: Accuracy = 0.8610
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      1607
#            1       0.69      0.53      0.60       393
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.73      0.76      2000
# weighted avg       0.85      0.86      0.85      2000
#
# [[1515   92]
#  [ 186  207]]
# Model saved as models/xgboost_featureEng_model.pkl

# %%
feature
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary            CLV  TenureAgeRatio  \
# 0                  1        101348.88       0.000000        0.047619
# ...

# %% [markdown]
# # SMOTE Technique

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
X_ressampled, Y_resampled = smote.fit_resample(X_train, y_train)

# %%
evaluate_and_save_model(xgboost_model, X_train_resampled, X_test, y_train_resampled, y_test, 'models/xgboost_SMOTE_model.pkl')
# Out:
# -------------------------
# XGBClassifier: Accuracy = 0.8570
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.90      0.93      0.91      1607
#            1       0.65      0.58      0.61       393
#
#     accuracy                           0.86      2000
#    macro avg       0.78      0.75      0.76      2000
# weighted avg       0.85      0.86      0.85      2000
#
# [[1487  120]
#  [ 166  227]]
# Model saved as models/xgboost_SMOTE_model.pkl

# %% [markdown]
# # ENsambeling
#
# voting classifier from sklearn which combines voting from multiple models

# %%
from sklearn.ensemble import VotingClassifier

# %%
voting_clf = VotingClassifier(estimators=[
    ('xgb', xgb.XGBClassifier(random_state=42)),
    ('dt', DecisionTreeClassifier(random_state=42)),
    ('rf', RandomForestClassifier(random_state=42)),
    ('nb', GaussianNB()),
    # `('knn', KNeighborsClassifier()),
    ('svm', SVC(random_state=42, probability=True))
], voting='soft')

# %%
evaluate_and_save_model(voting_clf, X_ressampled, X_test, Y_resampled, y_test, 'models/voting_clf.pkl')
# this is done by setting the voting param HARD
# Out:
# -------------------------
# VotingClassifier: Accuracy = 0.8455
# Classification Report :
#                precision    recall  f1-score   support
#
#            0       0.91      0.90      0.90      1607
#            1       0.60      0.64      0.62       393
#
#     accuracy                           0.85      2000
#    macro avg       0.76      0.77      0.76      2000
# weighted avg       0.85      0.85      0.85      2000
#
# [[1439  168]
#  [ 141  252]]
# Model saved as models/voting_clf.pkl
